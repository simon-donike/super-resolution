# %%
from sentinelsat.sentinel import SentinelAPI, read_geojson, geojson_to_wkt
import pandas as pd
from collections import OrderedDict
from datetime import date
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import fiona
import shapely
import datetime

# %%
"""
AOI Parameters
"""

# bbox
bbox = (-4.860230,47.428380,-0.982056,48.897512)
bbox_poly = shapely.geometry.box(*bbox, ccw=True)


# start-end times
start = datetime.datetime(2018,4,1)
end = datetime.datetime(2018,9,30)

# %%
# define tiles
tiles = ['30UUU', '30UVV', '30UVU', '30TVT', '30UWU', '30TWT', '30UXU']


# set up API
user = "sdonike" ####### ## change this!
pw =  "JH9EZFHhfySLRqTvZR8q" ######## ## change this!
api = SentinelAPI(user, pw, api_url='https://scihub.copernicus.eu/dhus', show_progressbars= True,timeout=200)

# %%
def get_footprints(tiles,lower_cloud,upper_cloud,producttype,processinglevel):
    # set query params
    query_kwargs = {
        'platformname': 'Sentinel-2',
        #S2B_MSIL2A_20180929T110829_N0208_R137_T30TWT_20180929T155623,
        #'producttype': producttype,
        'filename' : 'S2B_MSIL1C_20211105T112149_N0301_R037_T30UWU_20211108T162544.SAFE',
        #'processinglevel' : processinglevel,
        #'date': ('20180401', '20180930'),
        #'cloudcoverpercentage': (lower_cloud, upper_cloud),
        # 'limit': 999
    } 
    
    #products_ls = []
    footprints = []

    products = OrderedDict()
    for tile in tiles:
        products = OrderedDict()
        kw = query_kwargs.copy()
        kw['tileid'] = tile  
        pp = api.query(**kw)
        products.update(pp)
        #products_ls.append(products)
        print("Min. CC:",lower_cloud,"- Max. CC",upper_cloud,"\tTile:",tile,"\t - Products:",len(products))


        products_df = api.to_dataframe(products)
        #products_df_sorted = products_df.sort_values(['size'],ascending = [False])
        #products_df_sorted = products_df_sorted.head (1)

        #print(products_df_sorted['size'])
        #print(products_df_sorted['title'])

        fp = []
        for i in products_df_sorted["footprint"]:
            fp.append(i)

        #tmp_ls = [products_df_sorted["title"],products_df_sorted["tileid"],products_df_sorted["footprint"],products_df_sorted["datatakesensingstart"]]

        footprints.append(fp)


        #download data
        # api.download_all(products_df_sorted.index, directory_path= r'C:\Users\EQuilibrium\PyBegining\downloader\Downld_Sen',max_attempts=2, checksum = True )
        #api.download(products_df_sorted.index, directory_path= r'C:\Users\EQuilibrium\PyBegining\downloader\Downld_Sen', checksum = True )
        #print(products_df_sorted)
    # flatten list
    footprints = [item for sublist in footprints for item in sublist]
    footprints_df = pd.DataFrame(footprints,columns=["geometry"])
    #footprints_df
    
    footprints_df['geometry'] = gpd.GeoSeries.from_wkt(footprints_df['geometry'])
    gdf = gpd.GeoDataFrame(footprints_df, geometry='geometry')

    return(gdf)

# %%
get_footprints(tiles,0, 50,"S2MSI1C","Level-1C").to_file('qgis_files/sen2_tiles/footprints_05.shp')
#get_footprints(tiles,0,50,"S2MSI1C","Level-1C").to_file('qgis_files/sen2_tiles/footprints_10.shp')  
#get_footprints(tiles,10,15,"S2MSI1C","Level-1C").to_file('qgis_files/sen2_tiles/footprints_15.shp')  
#get_footprints(tiles,15,20,"S2MSI1C","Level-1C").to_file('qgis_files/sen2_tiles/footprints_20.shp')
# Out:
# Min. CC: 0 - Max. CC 50 	Tile: 30UUU 	 - Products: 0
# Min. CC: 0 - Max. CC 50 	Tile: 30UVV 	 - Products: 0
# Min. CC: 0 - Max. CC 50 	Tile: 30UVU 	 - Products: 0
# Min. CC: 0 - Max. CC 50 	Tile: 30TVT 	 - Products: 0
# Min. CC: 0 - Max. CC 50 	Tile: 30UWU 	 - Products: 1
# Min. CC: 0 - Max. CC 50 	Tile: 30TWT 	 - Products: 0
# Min. CC: 0 - Max. CC 50 	Tile: 30UXU 	 - Products: 0

# %%
products
# Out:
# OrderedDict([('712ce4fa-596b-4fac-8368-91c999ac778c',
#               {'title': 'S2B_MSIL1C_20210923T110659_N0301_R137_T30UXU_20210923T120609',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('712ce4fa-596b-4fac-8368-91c999ac778c')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('712ce4fa-596b-4fac-8368-91c999ac778c')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('712ce4fa-596b-4fac-8368-91c999ac778c')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-09-23T11:06:59.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 782.24 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 9, 23, 11, 6, 59, 24000),
#                'generationdate': datetime.datetime(2021, 9, 23, 12, 6, 9),
#                'beginposition': datetime.datetime(2021, 9, 23, 11, 6, 59, 24000),
#                'endposition': datetime.datetime(2021, 9, 23, 11, 6, 59, 24000),
#                'ingestiondate': datetime.datetime(2021, 9, 23, 13, 44, 18, 782000),
#                'orbitnumber': 23758,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 8.7126,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.3150507777844,-0.16973877 48.2982365192507,-0.1774292 48.15352846140552,-0.24359131 48.142153380989214,-0.24871826 48.00959752716624,-0.30856323 47.86474433776092,-0.37387085 47.73518954644745,-0.43203735 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.3150507777844,-0.16973877</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.43203735 47.73518954644745, -0.37387085 47.86474433776092, -0.30856323 48.00959752716624, -0.24871826 48.142153380989214, -0.24359131 48.15352846140552, -0.1774292 48.2982365192507, -0.16973877 48.3150507777844, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.43203735 47.73518954644745)))',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210923T120609_A023758_T30UXU_N03.01',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.01',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20210923T110659_N0301_R137_T30UXU_20210923T120609.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '782.24 MB',
#                's2datatakeid': 'GS2B_20210923T110659_023758_N03.01',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS4_20210923T120609_S20210923T110847_N03.01',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210923T120609_A023758_T30UXU_N03.01',
#                'identifier': 'S2B_MSIL1C_20210923T110659_N0301_R137_T30UXU_20210923T120609',
#                'uuid': '712ce4fa-596b-4fac-8368-91c999ac778c'}),
#              ('ddaee397-6f50-4a4b-bee9-88186a734e3c',
#               {'title': 'S2A_MSIL1C_20210905T105621_N0301_R094_T30UXU_20210905T130404',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('ddaee397-6f50-4a4b-bee9-88186a734e3c')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('ddaee397-6f50-4a4b-bee9-88186a734e3c')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('ddaee397-6f50-4a4b-bee9-88186a734e3c')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-09-05T10:56:21.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 817.61 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 9, 5, 10, 56, 21, 24000),
#                'generationdate': datetime.datetime(2021, 9, 5, 13, 4, 4),
#                'beginposition': datetime.datetime(2021, 9, 5, 10, 56, 21, 24000),
#                'endposition': datetime.datetime(2021, 9, 5, 10, 56, 21, 24000),
#                'ingestiondate': datetime.datetime(2021, 9, 5, 14, 53, 50, 131000),
#                'orbitnumber': 32409,
#                'relativeorbitnumber': 94,
#                'cloudcoverpercentage': 12.9895,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.707404295723606,-1.6407166 48.744744421781526,-1.6266174 48.71769475117851,-0.14755249 47.73104447774509,-0.2019043 47.75740973734738,-1.6656799 48.707404295723606,-1.6407166</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.2019043 47.73104447774509, -0.14755249 48.71769475117851, -1.6266174 48.744744421781526, -1.6407166 48.707404295723606, -1.6656799 47.75740973734738, -0.2019043 47.73104447774509)))',
#                'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210905T130404_A032409_T30UXU_N03.01',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.01',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2A_MSIL1C_20210905T105621_N0301_R094_T30UXU_20210905T130404.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '817.61 MB',
#                's2datatakeid': 'GS2A_20210905T105621_032409_N03.01',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2015-028A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2A',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_VGS2_20210905T130404_S20210905T110445_N03.01',
#                'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210905T130404_A032409_T30UXU_N03.01',
#                'identifier': 'S2A_MSIL1C_20210905T105621_N0301_R094_T30UXU_20210905T130404',
#                'uuid': 'ddaee397-6f50-4a4b-bee9-88186a734e3c'}),
#              ('d12e9c68-f5da-43fa-8180-d01e717658c5',
#               {'title': 'S2B_MSIL1C_20210903T110619_N0301_R137_T30UXU_20210903T132000',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('d12e9c68-f5da-43fa-8180-d01e717658c5')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('d12e9c68-f5da-43fa-8180-d01e717658c5')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('d12e9c68-f5da-43fa-8180-d01e717658c5')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-09-03T11:06:19.025Z, Instrument: MSI, Satellite: Sentinel-2, Size: 765.71 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 9, 3, 11, 6, 19, 25000),
#                'generationdate': datetime.datetime(2021, 9, 3, 13, 20),
#                'beginposition': datetime.datetime(2021, 9, 3, 11, 6, 19, 25000),
#                'endposition': datetime.datetime(2021, 9, 3, 11, 6, 19, 25000),
#                'ingestiondate': datetime.datetime(2021, 9, 3, 15, 12, 43, 17000),
#                'orbitnumber': 23472,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 17.703,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.31351289479345,-0.16983032 48.20883957031928,-0.21746826 48.06393476151931,-0.28353882 47.918869422469925,-0.34872437 47.886800390391855,-0.36309814 47.77295336388596,-0.41430664 47.735174189104235,-0.43118286 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.31351289479345,-0.16983032</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.43118286 47.735174189104235, -0.41430664 47.77295336388596, -0.36309814 47.886800390391855, -0.34872437 47.918869422469925, -0.28353882 48.06393476151931, -0.21746826 48.20883957031928, -0.16983032 48.31351289479345, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.43118286 47.735174189104235)))',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS2_20210903T132000_A023472_T30UXU_N03.01',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.01',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20210903T110619_N0301_R137_T30UXU_20210903T132000.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '765.71 MB',
#                's2datatakeid': 'GS2B_20210903T110619_023472_N03.01',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS2_20210903T132000_S20210903T110750_N03.01',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS2_20210903T132000_A023472_T30UXU_N03.01',
#                'identifier': 'S2B_MSIL1C_20210903T110619_N0301_R137_T30UXU_20210903T132000',
#                'uuid': 'd12e9c68-f5da-43fa-8180-d01e717658c5'}),
#              ('85b3f502-66ab-4b4f-a160-ea7ad3e4b31c',
#               {'title': 'S2B_MSIL1C_20210814T110619_N0301_R137_T30UXU_20210814T120505',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('85b3f502-66ab-4b4f-a160-ea7ad3e4b31c')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('85b3f502-66ab-4b4f-a160-ea7ad3e4b31c')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('85b3f502-66ab-4b4f-a160-ea7ad3e4b31c')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-08-14T11:06:19.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 774.75 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 8, 14, 11, 6, 19, 24000),
#                'generationdate': datetime.datetime(2021, 8, 14, 12, 5, 5),
#                'beginposition': datetime.datetime(2021, 8, 14, 11, 6, 19, 24000),
#                'endposition': datetime.datetime(2021, 8, 14, 11, 6, 19, 24000),
#                'ingestiondate': datetime.datetime(2021, 8, 14, 13, 57, 58, 860000),
#                'orbitnumber': 23186,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 0.0,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.33198177670904,-0.16879272 48.29255127611573,-0.18685913 48.1476841076571,-0.25326538 48.0027154323454,-0.3189087 47.8578041531306,-0.38442993 47.735323263511006,-0.43945312 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.33198177670904,-0.16879272</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.43945312 47.735323263511006, -0.38442993 47.8578041531306, -0.3189087 48.0027154323454, -0.25326538 48.1476841076571, -0.18685913 48.29255127611573, -0.16879272 48.33198177670904, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.43945312 47.735323263511006)))',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210814T120505_A023186_T30UXU_N03.01',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.01',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20210814T110619_N0301_R137_T30UXU_20210814T120505.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '774.75 MB',
#                's2datatakeid': 'GS2B_20210814T110619_023186_N03.01',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS4_20210814T120505_S20210814T110935_N03.01',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210814T120505_A023186_T30UXU_N03.01',
#                'identifier': 'S2B_MSIL1C_20210814T110619_N0301_R137_T30UXU_20210814T120505',
#                'uuid': '85b3f502-66ab-4b4f-a160-ea7ad3e4b31c'}),
#              ('1934ee79-c383-43fe-bf00-a0b2162c5def',
#               {'title': 'S2B_MSIL1C_20210722T105619_N0301_R094_T30UXU_20210722T115604',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('1934ee79-c383-43fe-bf00-a0b2162c5def')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('1934ee79-c383-43fe-bf00-a0b2162c5def')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('1934ee79-c383-43fe-bf00-a0b2162c5def')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-07-22T10:56:19.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 801.97 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 7, 22, 10, 56, 19, 24000),
#                'generationdate': datetime.datetime(2021, 7, 22, 11, 56, 4),
#                'beginposition': datetime.datetime(2021, 7, 22, 10, 56, 19, 24000),
#                'endposition': datetime.datetime(2021, 7, 22, 10, 56, 19, 24000),
#                'ingestiondate': datetime.datetime(2021, 7, 22, 14, 5, 46, 680000),
#                'orbitnumber': 22857,
#                'relativeorbitnumber': 94,
#                'cloudcoverpercentage': 1.6011000000000002,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.71532198639604,-1.6405029 48.744795371310424,-1.6293945 48.71769475117851,-0.14755249 47.73104447774509,-0.2019043 47.75740973734738,-1.6656799 48.71532198639604,-1.6405029</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.2019043 47.73104447774509, -0.14755249 48.71769475117851, -1.6293945 48.744795371310424, -1.6405029 48.71532198639604, -1.6656799 47.75740973734738, -0.2019043 47.73104447774509)))',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210722T115604_A022857_T30UXU_N03.01',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.01',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20210722T105619_N0301_R094_T30UXU_20210722T115604.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '801.97 MB',
#                's2datatakeid': 'GS2B_20210722T105619_022857_N03.01',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS4_20210722T115604_S20210722T105914_N03.01',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210722T115604_A022857_T30UXU_N03.01',
#                'identifier': 'S2B_MSIL1C_20210722T105619_N0301_R094_T30UXU_20210722T115604',
#                'uuid': '1934ee79-c383-43fe-bf00-a0b2162c5def'}),
#              ('47830f66-8d6b-45bf-b54f-a2b859294251',
#               {'title': 'S2A_MSIL1C_20210720T110621_N0301_R137_T30UXU_20210720T132532',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('47830f66-8d6b-45bf-b54f-a2b859294251')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('47830f66-8d6b-45bf-b54f-a2b859294251')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('47830f66-8d6b-45bf-b54f-a2b859294251')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-07-20T11:06:21.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 778.30 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 7, 20, 11, 6, 21, 24000),
#                'generationdate': datetime.datetime(2021, 7, 20, 13, 25, 32),
#                'beginposition': datetime.datetime(2021, 7, 20, 11, 6, 21, 24000),
#                'endposition': datetime.datetime(2021, 7, 20, 11, 6, 21, 24000),
#                'ingestiondate': datetime.datetime(2021, 7, 20, 15, 18, 57, 257000),
#                'orbitnumber': 31737,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 0.8901000000000001,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.32891658273734,-0.16897583 48.26170799274311,-0.19989014 48.11677435790004,-0.26608276 47.971920772236494,-0.33169556 47.82709265986818,-0.3968811 47.73529773109481,-0.43804932 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.32891658273734,-0.16897583</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.43804932 47.73529773109481, -0.3968811 47.82709265986818, -0.33169556 47.971920772236494, -0.26608276 48.11677435790004, -0.19989014 48.26170799274311, -0.16897583 48.32891658273734, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.43804932 47.73529773109481)))',
#                'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210720T132532_A031737_T30UXU_N03.01',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.01',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2A_MSIL1C_20210720T110621_N0301_R137_T30UXU_20210720T132532.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '778.30 MB',
#                's2datatakeid': 'GS2A_20210720T110621_031737_N03.01',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2015-028A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2A',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_VGS2_20210720T132532_S20210720T111452_N03.01',
#                'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210720T132532_A031737_T30UXU_N03.01',
#                'identifier': 'S2A_MSIL1C_20210720T110621_N0301_R137_T30UXU_20210720T132532',
#                'uuid': '47830f66-8d6b-45bf-b54f-a2b859294251'}),
#              ('44d71d0d-b9a9-4894-9478-024b504cae66',
#               {'title': 'S2A_MSIL1C_20210717T105621_N0301_R094_T30UXU_20210717T131629',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('44d71d0d-b9a9-4894-9478-024b504cae66')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('44d71d0d-b9a9-4894-9478-024b504cae66')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('44d71d0d-b9a9-4894-9478-024b504cae66')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-07-17T10:56:21.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 799.52 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 7, 17, 10, 56, 21, 24000),
#                'generationdate': datetime.datetime(2021, 7, 17, 13, 16, 29),
#                'beginposition': datetime.datetime(2021, 7, 17, 10, 56, 21, 24000),
#                'endposition': datetime.datetime(2021, 7, 17, 10, 56, 21, 24000),
#                'ingestiondate': datetime.datetime(2021, 7, 17, 15, 7, 20, 822000),
#                'orbitnumber': 31694,
#                'relativeorbitnumber': 94,
#                'cloudcoverpercentage': 0.0738,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.70637824591161,-1.6407471 48.7447372281774,-1.6262207 48.71769475117851,-0.14755249 47.73104447774509,-0.2019043 47.75740973734738,-1.6656799 48.70637824591161,-1.6407471</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.2019043 47.73104447774509, -0.14755249 48.71769475117851, -1.6262207 48.7447372281774, -1.6407471 48.70637824591161, -1.6656799 47.75740973734738, -0.2019043 47.73104447774509)))',
#                'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210717T131629_A031694_T30UXU_N03.01',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.01',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2A_MSIL1C_20210717T105621_N0301_R094_T30UXU_20210717T131629.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '799.52 MB',
#                's2datatakeid': 'GS2A_20210717T105621_031694_N03.01',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2015-028A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2A',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_VGS2_20210717T131629_S20210717T110307_N03.01',
#                'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210717T131629_A031694_T30UXU_N03.01',
#                'identifier': 'S2A_MSIL1C_20210717T105621_N0301_R094_T30UXU_20210717T131629',
#                'uuid': '44d71d0d-b9a9-4894-9478-024b504cae66'}),
#              ('d925487a-5743-4acc-b6a1-7e1575d0c69d',
#               {'title': 'S2B_MSIL1C_20210615T110619_N0300_R137_T30UXU_20210615T131705',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('d925487a-5743-4acc-b6a1-7e1575d0c69d')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('d925487a-5743-4acc-b6a1-7e1575d0c69d')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('d925487a-5743-4acc-b6a1-7e1575d0c69d')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-06-15T11:06:19.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 784.24 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 6, 15, 11, 6, 19, 24000),
#                'generationdate': datetime.datetime(2021, 6, 15, 13, 17, 5),
#                'beginposition': datetime.datetime(2021, 6, 15, 11, 6, 19, 24000),
#                'endposition': datetime.datetime(2021, 6, 15, 11, 6, 19, 24000),
#                'ingestiondate': datetime.datetime(2021, 6, 15, 16, 49, 27, 675000),
#                'orbitnumber': 22328,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 16.3049,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.340471966639996,-0.16833496 48.31793907262346,-0.1786499 48.17307215729228,-0.24520874 48.02810506766684,-0.3109131 47.88320355723543,-0.37649536 47.73831574425123,-0.4416504 47.73538616430295,-0.44296265 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.340471966639996,-0.16833496</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.44296265 47.73538616430295, -0.4416504 47.73831574425123, -0.37649536 47.88320355723543, -0.3109131 48.02810506766684, -0.24520874 48.17307215729228, -0.1786499 48.31793907262346, -0.16833496 48.340471966639996, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.44296265 47.73538616430295)))',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS2_20210615T131705_A022328_T30UXU_N03.00',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.00',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20210615T110619_N0300_R137_T30UXU_20210615T131705.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '784.24 MB',
#                's2datatakeid': 'GS2B_20210615T110619_022328_N03.00',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS2_20210615T131705_S20210615T111721_N03.00',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS2_20210615T131705_A022328_T30UXU_N03.00',
#                'identifier': 'S2B_MSIL1C_20210615T110619_N0300_R137_T30UXU_20210615T131705',
#                'uuid': 'd925487a-5743-4acc-b6a1-7e1575d0c69d'}),
#              ('44cb805e-2526-424a-83e6-b29c8b391103',
#               {'title': 'S2B_MSIL1C_20210605T110619_N0300_R137_T30UXU_20210605T132757',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('44cb805e-2526-424a-83e6-b29c8b391103')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('44cb805e-2526-424a-83e6-b29c8b391103')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('44cb805e-2526-424a-83e6-b29c8b391103')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-06-05T11:06:19.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 778.03 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 6, 5, 11, 6, 19, 24000),
#                'generationdate': datetime.datetime(2021, 6, 5, 13, 27, 57),
#                'beginposition': datetime.datetime(2021, 6, 5, 11, 6, 19, 24000),
#                'endposition': datetime.datetime(2021, 6, 5, 11, 6, 19, 24000),
#                'ingestiondate': datetime.datetime(2021, 6, 5, 15, 32, 20, 574000),
#                'orbitnumber': 22185,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 0.1965,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.342308387760696,-0.16824341 48.32874154888417,-0.174469 48.18396603681007,-0.240448 48.03913353154293,-0.30612183 47.89428480833924,-0.37164307 47.7493525953004,-0.43701172 47.735392341874515,-0.44329834 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.342308387760696,-0.16824341</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.44329834 47.735392341874515, -0.43701172 47.7493525953004, -0.37164307 47.89428480833924, -0.30612183 48.03913353154293, -0.240448 48.18396603681007, -0.174469 48.32874154888417, -0.16824341 48.342308387760696, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.44329834 47.735392341874515)))',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS2_20210605T132757_A022185_T30UXU_N03.00',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.00',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20210605T110619_N0300_R137_T30UXU_20210605T132757.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '778.03 MB',
#                's2datatakeid': 'GS2B_20210605T110619_022185_N03.00',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS2_20210605T132757_S20210605T111526_N03.00',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS2_20210605T132757_A022185_T30UXU_N03.00',
#                'identifier': 'S2B_MSIL1C_20210605T110619_N0300_R137_T30UXU_20210605T132757',
#                'uuid': '44cb805e-2526-424a-83e6-b29c8b391103'}),
#              ('2545c0a9-0db3-48ea-b9ed-6de9b1b7d069',
#               {'title': 'S2A_MSIL1C_20210531T110621_N0300_R137_T30UXU_20210531T132211',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('2545c0a9-0db3-48ea-b9ed-6de9b1b7d069')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('2545c0a9-0db3-48ea-b9ed-6de9b1b7d069')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('2545c0a9-0db3-48ea-b9ed-6de9b1b7d069')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-05-31T11:06:21.025Z, Instrument: MSI, Satellite: Sentinel-2, Size: 787.14 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 5, 31, 11, 6, 21, 25000),
#                'generationdate': datetime.datetime(2021, 5, 31, 13, 22, 11),
#                'beginposition': datetime.datetime(2021, 5, 31, 11, 6, 21, 25000),
#                'endposition': datetime.datetime(2021, 5, 31, 11, 6, 21, 25000),
#                'ingestiondate': datetime.datetime(2021, 5, 31, 15, 18, 47, 565000),
#                'orbitnumber': 31022,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 0.0,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.323856463301354,-0.16925049 48.231569620217,-0.21148682 48.0867694055763,-0.27749634 47.94177879626143,-0.34280396 47.796802504966806,-0.4083557 47.735261212096944,-0.43600464 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.323856463301354,-0.16925049</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.43600464 47.735261212096944, -0.4083557 47.796802504966806, -0.34280396 47.94177879626143, -0.27749634 48.0867694055763, -0.21148682 48.231569620217, -0.16925049 48.323856463301354, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.43600464 47.735261212096944)))',
#                'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210531T132211_A031022_T30UXU_N03.00',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.00',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2A_MSIL1C_20210531T110621_N0300_R137_T30UXU_20210531T132211.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '787.14 MB',
#                's2datatakeid': 'GS2A_20210531T110621_031022_N03.00',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2015-028A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2A',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_VGS2_20210531T132211_S20210531T111450_N03.00',
#                'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210531T132211_A031022_T30UXU_N03.00',
#                'identifier': 'S2A_MSIL1C_20210531T110621_N0300_R137_T30UXU_20210531T132211',
#                'uuid': '2545c0a9-0db3-48ea-b9ed-6de9b1b7d069'}),
#              ('8cef84c1-4f97-42a2-9fd3-5d2033b227ff',
#               {'title': 'S2A_MSIL1C_20210528T105621_N0300_R094_T30UXU_20210528T131537',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cef84c1-4f97-42a2-9fd3-5d2033b227ff')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cef84c1-4f97-42a2-9fd3-5d2033b227ff')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('8cef84c1-4f97-42a2-9fd3-5d2033b227ff')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-05-28T10:56:21.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 806.87 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 5, 28, 10, 56, 21, 24000),
#                'generationdate': datetime.datetime(2021, 5, 28, 13, 15, 37),
#                'beginposition': datetime.datetime(2021, 5, 28, 10, 56, 21, 24000),
#                'endposition': datetime.datetime(2021, 5, 28, 10, 56, 21, 24000),
#                'ingestiondate': datetime.datetime(2021, 5, 28, 15, 6, 13, 269000),
#                'orbitnumber': 30979,
#                'relativeorbitnumber': 94,
#                'cloudcoverpercentage': 15.2102,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.69901861414116,-1.640928468336821 48.74469117207855,-1.623703059770898 48.71769475117851,-0.147561291526931 47.73104447774509,-0.201905284697073 47.75740973734738,-1.665668651033201 48.69901861414116,-1.640928468336821</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.201905284697073 47.73104447774509, -0.147561291526931 48.71769475117851, -1.623703059770898 48.74469117207855, -1.640928468336821 48.69901861414116, -1.665668651033201 47.75740973734738, -0.201905284697073 47.73104447774509)))',
#                'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210528T131537_A030979_T30UXU_N03.00',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.00',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2A_MSIL1C_20210528T105621_N0300_R094_T30UXU_20210528T131537.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '806.87 MB',
#                's2datatakeid': 'GS2A_20210528T105621_030979_N03.00',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2015-028A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2A',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_VGS2_20210528T131537_S20210528T110445_N03.00',
#                'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210528T131537_A030979_T30UXU_N03.00',
#                'identifier': 'S2A_MSIL1C_20210528T105621_N0300_R094_T30UXU_20210528T131537',
#                'uuid': '8cef84c1-4f97-42a2-9fd3-5d2033b227ff'}),
#              ('3f6493a1-dc83-43c9-98a8-3776a071a49d',
#               {'title': 'S2B_MSIL1C_20210423T105619_N0300_R094_T30UXU_20210423T115904',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('3f6493a1-dc83-43c9-98a8-3776a071a49d')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('3f6493a1-dc83-43c9-98a8-3776a071a49d')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('3f6493a1-dc83-43c9-98a8-3776a071a49d')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-04-23T10:56:19.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 805.57 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 4, 23, 10, 56, 19, 24000),
#                'generationdate': datetime.datetime(2021, 4, 23, 11, 59, 4),
#                'beginposition': datetime.datetime(2021, 4, 23, 10, 56, 19, 24000),
#                'endposition': datetime.datetime(2021, 4, 23, 10, 56, 19, 24000),
#                'ingestiondate': datetime.datetime(2021, 4, 23, 15, 19, 31, 153000),
#                'orbitnumber': 21570,
#                'relativeorbitnumber': 94,
#                'cloudcoverpercentage': 0.0,
#                'sensoroperationalmode': 'INS-NOBS',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.68876752095493,-1.6412048 48.70600469104484,-1.6347351 48.74462499069976,-1.6200867 48.71769475117851,-0.14755249 47.73104447774509,-0.2019043 47.75740973734738,-1.6656799 48.68876752095493,-1.6412048</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'footprint': 'MULTIPOLYGON (((-0.2019043 47.73104447774509, -0.14755249 48.71769475117851, -1.6200867 48.74462499069976, -1.6347351 48.70600469104484, -1.6412048 48.68876752095493, -1.6656799 47.75740973734738, -0.2019043 47.73104447774509)))',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210423T115904_A021570_T30UXU_N03.00',
#                'tileid': '30UXU',
#                'hv_order_tileid': 'UU30X',
#                'format': 'SAFE',
#                'processingbaseline': '03.00',
#                'platformname': 'Sentinel-2',
#                'filename': 'S2B_MSIL1C_20210423T105619_N0300_R094_T30UXU_20210423T115904.SAFE',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'instrumentshortname': 'MSI',
#                'size': '805.57 MB',
#                's2datatakeid': 'GS2B_20210423T105619_021570_N03.00',
#                'producttype': 'S2MSI1C',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processinglevel': 'Level-1C',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS4_20210423T115904_S20210423T105910_N03.00',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210423T115904_A021570_T30UXU_N03.00',
#                'identifier': 'S2B_MSIL1C_20210423T105619_N0300_R094_T30UXU_20210423T115904',
#                'uuid': '3f6493a1-dc83-43c9-98a8-3776a071a49d'}),
#              ('7d3f532c-0877-4d4d-9e5f-8db093e87938',
#               {'title': 'S2B_MSIL1C_20210413T105619_N0300_R094_T30UXU_20210413T115522',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('7d3f532c-0877-4d4d-9e5f-8db093e87938')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('7d3f532c-0877-4d4d-9e5f-8db093e87938')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('7d3f532c-0877-4d4d-9e5f-8db093e87938')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-04-13T10:56:19.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 793.68 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 4, 13, 10, 56, 19, 24000),
#                'ingestiondate': datetime.datetime(2021, 4, 13, 15, 3, 3, 102000),
#                'beginposition': datetime.datetime(2021, 4, 13, 10, 56, 19, 24000),
#                'endposition': datetime.datetime(2021, 4, 13, 10, 56, 19, 24000),
#                'generationdate': datetime.datetime(2021, 4, 13, 11, 55, 22),
#                'orbitnumber': 21427,
#                'relativeorbitnumber': 94,
#                'cloudcoverpercentage': 0.0735,
#                'filename': 'S2B_MSIL1C_20210413T105619_N0300_R094_T30UXU_20210413T115522.SAFE',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.699724289330604,-1.6408997 48.70405769035247,-1.6392822 48.74469436290414,-1.6238708 48.71769475117851,-0.14755249 47.73104447774509,-0.2019043 47.75740973734738,-1.6656799 48.699724289330604,-1.6408997</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'format': 'SAFE',
#                'identifier': 'S2B_MSIL1C_20210413T105619_N0300_R094_T30UXU_20210413T115522',
#                'instrumentshortname': 'MSI',
#                'sensoroperationalmode': 'INS-NOBS',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'footprint': 'MULTIPOLYGON (((-0.2019043 47.73104447774509, -0.14755249 48.71769475117851, -1.6238708 48.74469436290414, -1.6392822 48.70405769035247, -1.6408997 48.699724289330604, -1.6656799 47.75740973734738, -0.2019043 47.73104447774509)))',
#                's2datatakeid': 'GS2B_20210413T105619_021427_N03.00',
#                'platformidentifier': '2017-013A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2B',
#                'processingbaseline': '03.00',
#                'processinglevel': 'Level-1C',
#                'producttype': 'S2MSI1C',
#                'platformname': 'Sentinel-2',
#                'size': '793.68 MB',
#                'tileid': '30UXU',
#                'datastripidentifier': 'S2B_OPER_MSI_L1C_DS_VGS4_20210413T115522_S20210413T105912_N03.00',
#                'granuleidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210413T115522_A021427_T30UXU_N03.00',
#                'hv_order_tileid': 'UU30X',
#                'level1cpdiidentifier': 'S2B_OPER_MSI_L1C_TL_VGS4_20210413T115522_A021427_T30UXU_N03.00',
#                'uuid': '7d3f532c-0877-4d4d-9e5f-8db093e87938'}),
#              ('eb8e1173-6b35-4905-8d83-ed4bbc0a65a6',
#               {'title': 'S2A_MSIL1C_20210401T110621_N0300_R137_T30UXU_20210401T131536',
#                'link': "https://scihub.copernicus.eu/dhus/odata/v1/Products('eb8e1173-6b35-4905-8d83-ed4bbc0a65a6')/$value",
#                'link_alternative': "https://scihub.copernicus.eu/dhus/odata/v1/Products('eb8e1173-6b35-4905-8d83-ed4bbc0a65a6')/",
#                'link_icon': "https://scihub.copernicus.eu/dhus/odata/v1/Products('eb8e1173-6b35-4905-8d83-ed4bbc0a65a6')/Products('Quicklook')/$value",
#                'summary': 'Date: 2021-04-01T11:06:21.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 733.20 MB',
#                'ondemand': 'false',
#                'datatakesensingstart': datetime.datetime(2021, 4, 1, 11, 6, 21, 24000),
#                'ingestiondate': datetime.datetime(2021, 4, 1, 15, 37, 51, 32000),
#                'beginposition': datetime.datetime(2021, 4, 1, 11, 6, 21, 24000),
#                'endposition': datetime.datetime(2021, 4, 1, 11, 6, 21, 24000),
#                'generationdate': datetime.datetime(2021, 4, 1, 13, 15, 36),
#                'orbitnumber': 30164,
#                'relativeorbitnumber': 137,
#                'cloudcoverpercentage': 0.0,
#                'filename': 'S2A_MSIL1C_20210401T110621_N0300_R137_T30UXU_20210401T131536.SAFE',
#                'gmlfootprint': '<gml:Polygon srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" xmlns:gml="http://www.opengis.net/gml">\n   <gml:outerBoundaryIs>\n      <gml:LinearRing>\n         <gml:coordinates>48.32991296809309,-0.1689148 48.24722484600997,-0.20709229 48.1022774722132,-0.27313232 47.95737553808004,-0.33877563 47.812471881834576,-0.4038391 47.73530316350868,-0.4383545 47.75740973734738,-1.6656799 48.74498411169783,-1.6397095 48.71769475117851,-0.14755249 48.32991296809309,-0.1689148</gml:coordinates>\n      </gml:LinearRing>\n   </gml:outerBoundaryIs>\n</gml:Polygon>',
#                'format': 'SAFE',
#                'identifier': 'S2A_MSIL1C_20210401T110621_N0300_R137_T30UXU_20210401T131536',
#                'instrumentshortname': 'MSI',
#                'sensoroperationalmode': 'INS-NOBS',
#                'instrumentname': 'Multi-Spectral Instrument',
#                'footprint': 'MULTIPOLYGON (((-0.4383545 47.73530316350868, -0.4038391 47.812471881834576, -0.33877563 47.95737553808004, -0.27313232 48.1022774722132, -0.20709229 48.24722484600997, -0.1689148 48.32991296809309, -0.14755249 48.71769475117851, -1.6397095 48.74498411169783, -1.6656799 47.75740973734738, -0.4383545 47.73530316350868)))',
#                's2datatakeid': 'GS2A_20210401T110621_030164_N03.00',
#                'platformidentifier': '2015-028A',
#                'orbitdirection': 'DESCENDING',
#                'platformserialidentifier': 'Sentinel-2A',
#                'processingbaseline': '03.00',
#                'processinglevel': 'Level-1C',
#                'producttype': 'S2MSI1C',
#                'platformname': 'Sentinel-2',
#                'size': '733.20 MB',
#                'tileid': '30UXU',
#                'datastripidentifier': 'S2A_OPER_MSI_L1C_DS_VGS2_20210401T131536_S20210401T111446_N03.00',
#                'granuleidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210401T131536_A030164_T30UXU_N03.00',
#                'hv_order_tileid': 'UU30X',
#                'level1cpdiidentifier': 'S2A_OPER_MSI_L1C_TL_VGS2_20210401T131536_A030164_T30UXU_N03.00',
#                'uuid': 'eb8e1173-6b35-4905-8d83-ed4bbc0a65a6'})])

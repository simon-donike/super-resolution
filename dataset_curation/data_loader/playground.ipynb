# %%
import geopandas
import numpy

# %%
df = geopandas.read_file("train_test_split.gpkg")

# %%
df = df.fillna("train")

# %%
df.to_file("train_test.gpkg", driver="GPKG")

# %%
import pandas as pd

# %%
a = pd.read_pickle("final_dataset.pkl")

# %%
b = []
for i in a["other_valid_acq"]:
    b.append(len(i))
a["count_sen2"] = b

# %%
a.to_csv("sen2_count.csv")

# %%
a[a[""]]
# Out:
#        index         x          y                        geometry  \
# 0          0   99000.0  6843750.0   POINT (99000.000 6843750.000)
# 1          1   99000.0  6844500.0   POINT (99000.000 6844500.000)
# 2          2   99000.0  6845250.0   POINT (99000.000 6845250.000)
# 3          3   99000.0  6846000.0   POINT (99000.000 6846000.000)
# 4          3   99000.0  6846000.0   POINT (99000.000 6846000.000)
# ...      ...       ...        ...                             ...
# 82594  53585  401250.0  6828000.0  POINT (401250.000 6828000.000)
# 82595  53586  401250.0  6828750.0  POINT (401250.000 6828750.000)
# 82596  53587  401250.0  6829500.0  POINT (401250.000 6829500.000)
# 82597  53588  401250.0  6830250.0  POINT (401250.000 6830250.000)
# 82598  53589  401250.0  6831000.0  POINT (401250.000 6831000.000)
#
#        index_right                               name  min  max  \
# 0             1967  ORT_2018_0099_6846_LA93_8Bits.jp2    1  144
# ...

# %%
a.columns
# Out:
# Index(['index', 'x', 'y', 'geometry', 'index_right', 'name', 'min', 'max',
#        'other_acq', 'geom', 'other_valid_acq', 'spot6_validity', 'count_sen2'],
#       dtype='object')
